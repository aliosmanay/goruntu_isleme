# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B837-29A2
#
#  Directory of C:\Users\AliOsman
#
# 20.10.2017  15:43    <DIR>          .
# 20.10.2017  15:43    <DIR>          ..
# 26.03.2015  20:27    <DIR>          .android
# 26.03.2015  19:46    <DIR>          .AndroidStudio
# 19.10.2016  17:14    <DIR>          .eclipse
# 21.03.2017  09:52    <DIR>          .gimp-2.8
# 26.03.2015  20:28    <DIR>          .gradle
# 29.12.2015  22:43    <DIR>          .idlerc
# 20.10.2017  15:43    <DIR>          .ipynb_checkpoints
# 19.10.2017  23:12    <DIR>          .ipython
# 30.01.2017  10:45    <DIR>          .jmonkeyplatform
# 30.01.2017  10:44    <DIR>          .jmonkeyplatform-installer
# 20.10.2017  13:16    <DIR>          .jupyter
# 20.10.2017  15:18    <DIR>          .matplotlib
# 12.02.2017  12:24    <DIR>          .nbi
# 01.05.2017  23:32                 0 .node_repl_history
# 03.10.2016  23:49    <DIR>          .oracle_jre_usage
# 18.09.2016  15:47    <DIR>          .Origin
# 06.02.2017  11:28    <DIR>          .p2
# 18.09.2016  15:47    <DIR>          .QtWebEngineProcess
# 19.12.2016  00:47    <DIR>          .thumbnails
# 03.10.2016  23:54    <DIR>          .tooling
# 01.05.2017  21:02    <DIR>          .vscode
# 13.01.2016  14:59    <DIR>          3D Objects
# 02.05.2017  11:33    <DIR>          Anaconda3
# 26.03.2015  20:27    <DIR>          AndroidStudioProjects
# 17.02.2017  11:32    <DIR>          ansel
# 11.10.2017  14:01    <DIR>          Contacts
# 20.10.2017  15:09    <DIR>          Desktop
# 20.10.2017  14:54    <DIR>          Documents
# 11.10.2017  14:01    <DIR>          Downloads
# 03.10.2016  23:49    <DIR>          eclipse
# 11.10.2017  14:01    <DIR>          Favorites
# 11.10.2017  14:01    <DIR>          Links
# 11.10.2017  14:01    <DIR>          Music
# 09.05.2017  10:35    <DIR>          myp
# 20.09.2017  12:10    <DIR>          OneDrive
# 20.10.2017  14:54    <DIR>          Pictures
# 20.10.2017  15:08            18.238 plaka.jpg
# 11.10.2017  14:01    <DIR>          Saved Games
# 11.10.2017  14:01    <DIR>          Searches
# 16.12.2016  13:37    <DIR>          SkyDrive
# 31.05.2017  13:11           956.255 test_1.jpg
# 20.10.2017  15:43                72 Untitled.ipynb
# 20.10.2017  15:23           433.845 Untitled1.ipynb
# 19.10.2017  23:07    <DIR>          Videos
# 19.10.2016  17:14    <DIR>          workspace
#                5 File(s)      1.408.410 bytes
#               42 Dir(s)  17.503.735.808 bytes free

# %%
import matplotlib.pyplot as plt
import numpy as np
img_1=plt.imread("test_1.jpg")
img_1.ndim
img_1.shape
img_2=img_1[1:1080:2,1:1920:2]
img_2.ndim,img_2.shape
plt.imshow(img_2)
plt.show()
img_2
# Out:
# array([[[168, 107,  53],
#         [168, 107,  53],
#         [168, 107,  53],
#         ...,
#         [157, 105,  57],
#         [159, 107,  59],
#         [156, 104,  56]],
#
#        [[170, 109,  55],
#         [170, 109,  55],
#         [169, 108,  54],
#         ...,
#         [158, 104,  57],
#         [158, 108,  59],
#         [155, 105,  56]],
#
#        [[169, 108,  54],
#         [169, 108,  54],
#         [169, 108,  54],
#         ...,
#         [159, 105,  58],
#         [156, 104,  56],
#         [159, 107,  59]],
#
#        ...,
#        [[  4,   2,   3],
#         [  5,   3,   4],
#         [  4,   2,   3],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[  5,   3,   4],
#         [  5,   3,   4],
#         [  6,   4,   5],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  2,   2,   2]],
#
#        [[  4,   2,   3],
#         [  4,   2,   3],
#         [  6,   4,   5],
#         ...,
#         [  3,   3,   3],
#         [  4,   4,   4],
#         [  4,   4,   4]]], dtype=uint8)

# %%
plt.imshow(img_1,plt.cm.gray)
plt.show()

# %%
img_3=np.zeros((img_2.shape[0:2]))
img_3.shape
img_4=np.zeros((img_2.shape[0:2]))
img_4.shape
img_5=np.zeros((img_1.shape[0:2]))
img_2=img_1
img_2.shape,img_5.shape
threshold=100
for i in range(img_2.shape[0]):
    for j in range(img_2.shape[1]):
        n=img_2[i,j,0]/3 + img_2[i,j,1]/3 + img_2[i,j,2]/3
        img_3[i,j]=n
        if n > threshold:
            img_4[i,j] =255
        else:
            img_4[i,j]=0
plt.subplot(1,3,1),plt.imshow(img_2)
plt.subplot(1,3,2),plt.imshow(img_4, plt.cm.binary)
plt.show()

# %%
plt.imshow(img_3,plt.cm.gray)
plt.show()

# %%
plt.imshow(img_4, plt.cm.binary)
plt.show()

# %%
img_1=plt.imread("plaka.jpg")
img_1.ndim,img_1.shape
img_5=np.zeros((img_1.shape[0:2]))
img_2=img_1
img_2.shape,img_5.shape
threshold=100
for i in range(img_2.shape[0]):
    for j in range(img_2.shape[1]):
        n=img_2[i,j,0]/3 + img_2[i,j,1]/3 + img_2[i,j,2]/3
        img_3[i,j]=n
        if n > threshold:
            img_5[i,j] =255
        else:
            img_5[i,j]=0
plt.subplot(1,3,1),plt.imshow(img_2)
plt.subplot(1,3,2),plt.imshow(img_5, plt.cm.binary)
plt.show()
